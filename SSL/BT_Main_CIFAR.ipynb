# %% [markdown]
# <a href="https://colab.research.google.com/github/hamish-haggerty/AI-hacking/blob/master/SSL/BT_Main_CIFAR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/hamish-haggerty/base_rbt.git#egg='base_rbt'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting base_rbt
#   Cloning https://github.com/hamish-haggerty/base_rbt.git to /tmp/pip-install-l20d2lax/base-rbt_ec58d74811be4d1c80df3eb682972aee
#   Running command git clone -q https://github.com/hamish-haggerty/base_rbt.git /tmp/pip-install-l20d2lax/base-rbt_ec58d74811be4d1c80df3eb682972aee
# Requirement already satisfied: fastcore in /usr/local/lib/python3.7/dist-packages (from base_rbt) (1.5.27)
# Collecting kornia>=0.6.8
#   Downloading kornia-0.6.8-py2.py3-none-any.whl (551 kB)
#      |████████████████████████████████| 551 kB 5.0 MB/s
# Requirement already satisfied: fastai>=2.7.10 in /usr/local/lib/python3.7/dist-packages (from base_rbt) (2.7.10)
# Collecting self_supervised
#   Downloading self_supervised-1.0.4-py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 89 kB/s
# Requirement already satisfied: pillow>6.0.0 in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (7.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (1.7.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (6.0)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (0.0.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (2.23.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (1.0.2)
# Requirement already satisfied: pip in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (21.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (1.3.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (3.2.2)
# Requirement already satisfied: spacy<4 in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (3.4.3)
# Requirement already satisfied: torch<1.14,>=1.7 in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (1.12.1+cu113)
# Requirement already satisfied: fastprogress>=0.2.4 in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (1.0.3)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from fastai>=2.7.10->base_rbt) (0.13.1+cu113)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (3.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (0.7.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (0.8.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (4.64.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (3.3.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (0.10.1)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (4.1.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (1.21.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (1.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (1.10.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (57.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (1.0.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (2.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (8.1.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (3.0.10)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (2.4.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<4->fastai>=2.7.10->base_rbt) (2.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy<4->fastai>=2.7.10->base_rbt) (3.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->fastai>=2.7.10->base_rbt) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<4->fastai>=2.7.10->base_rbt) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fastai>=2.7.10->base_rbt) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fastai>=2.7.10->base_rbt) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fastai>=2.7.10->base_rbt) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fastai>=2.7.10->base_rbt) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai>=2.7.10->base_rbt) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.7/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<4->fastai>=2.7.10->base_rbt) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.8.0,>=0.3.0->spacy<4->fastai>=2.7.10->base_rbt) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<4->fastai>=2.7.10->base_rbt) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->fastai>=2.7.10->base_rbt) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->fastai>=2.7.10->base_rbt) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->fastai>=2.7.10->base_rbt) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib->fastai>=2.7.10->base_rbt) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fastai>=2.7.10->base_rbt) (2022.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->fastai>=2.7.10->base_rbt) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->fastai>=2.7.10->base_rbt) (3.1.0)
# Collecting timm>=0.4.5
#   Downloading timm-0.6.12-py3-none-any.whl (549 kB)
#      |████████████████████████████████| 549 kB 87.0 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.11.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 96.6 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->timm>=0.4.5->self_supervised->base_rbt) (3.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->timm>=0.4.5->self_supervised->base_rbt) (4.13.0)
# Building wheels for collected packages: base-rbt
#   Building wheel for base-rbt (setup.py) ... done
#   Created wheel for base-rbt: filename=base_rbt-0.0.1-py3-none-any.whl size=20565 sha256=02e09d09020c6e193227f9061c834f7e7828871eb42c2505fbd2e86e4eac30f6
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2clo_nfa/wheels/7c/4c/c6/65c6f336ed53f534c05ca6736718e1e18f359920a1ef911674
# Successfully built base-rbt
# Installing collected packages: huggingface-hub, timm, kornia, self-supervised, base-rbt
# Successfully installed base-rbt-0.0.1 huggingface-hub-0.11.1 kornia-0.6.8 self-supervised-1.0.4 timm-0.6.12

# %%
#See commit  for state of system
from base_rbt.base_model import * 
from base_rbt.base_lf import *
from base_rbt.base_linear import *
from base_rbt.helper import *

# %%
import self_supervised
import torch
from fastai.vision.all import *
from self_supervised.augmentations import *
from self_supervised.layers import *
from statistics import mean

# %%
#Mount drive
from google.colab import drive
drive.mount('/content/drive')

#Make models directory
#import os
#os.makedirs('/content/drive/MyDrive/models')
# Out:
# Mounted at /content/drive

# %%
device='cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# **Ok now let's do an end to end CIFAR10 example. Let's comment a little more on the API as we go - this will be helpful when considering how to add functionality to (in particular) base_model**
#
# Here are the steps at a high level:
# - Define hps (e.g. batch size, projector dimension etc). Note that if the model changes then there may be different hps
# - Get the data (train, tune, test) -> dls,dls_val, dls_test
# - Patch in loss function definition
# - Setup/define augmentations, encoder, model, learner
# - Train BT/RBT (i.e. fit the learner
# - Train linear classifier and record performance

# %% [markdown]
# Step 1): We need the data, and to set all the hps.

# %%
#hps's
device ='cuda' if torch.cuda.is_available() else 'cpu'
cuda = (device=='cuda')
seed=42 #Will have to try with different random seeds. Two times is probably enough 
n_in=3
indim=1024 #find this by inspection, e.g. for resnet18 is 1024
size=32
ps=500 
bs=128 #for training BT
bs_val=128 #for training linear head
bs_test=500 #for evaluating linear head. Divides 10000
ts_val=bs_val*4 #so 512, ~ 1% of 50000
ts=50000#-ts_val #

n_epoch=600 #epochs for BT 
num_val = 5 #number of tune sets
numfit = 200 #epochs for linear classifer

# %%
#data: dls, dls_val, dls_test
#get the data: Need dls, dls_val, dls_test
path = untar_data(URLs.CIFAR)
fnames = get_image_files(path / "train")
fnames.sort()
#shuffle data (in reproducible way)
seed_everything(seed=seed)
fnames = fnames.shuffle()

#fnames for train, eval and test
fnames_train = fnames#[0:ts]
fnames_val = fnames[0:ts_val]

fnames_test = get_image_files(path / "test")
#fnames_test = fnames[ts+ts_val:ts+ts_val+ts_test]

def label_func(fname):
    return fname.name.split('_')[1].strip('png').strip('.')

#labels for train,eval and test
labels = [label_func(fname) for fname in fnames]
labels_train = labels#[0:ts]
#labels_val = labels[0:ts_val]
labels_test = [label_func(fname) for fname in fnames_test]

#Used for training encoder i.e. BT
dls = ImageDataLoaders.from_lists(path, fnames_train, labels_train,bs=bs, item_tfms=[Resize(size=size)], #batch_tfms=[ToTensor(), IntToFloatTensor()],
                                  valid_pct=0.0,num_workers=12,device=device,seed=seed)
#Used for training linear classifier

tune_dict={}
_val_dict = {} #just for debugging random seed 
for i in range(num_val):

    fnames_val = fnames[i*ts_val:(i+1)*ts_val]
    labels_val = labels[i*ts_val:(i+1)*ts_val]
    dls_val = ImageDataLoaders.from_lists(path, fnames_val, labels_val,bs=bs_val, item_tfms=[Resize(size=size)], #batch_tfms=[ToTensor(), IntToFloatTensor()],
                                    valid_pct=0.0,num_workers=12,device=device,seed=seed)
    
    tune_dict[i] = dls_val
    _val_dict[i] = fnames_val

#Used for evaluating linear classifier
dls_test = ImageDataLoaders.from_lists(path, fnames_test, labels_test,bs=bs_test, item_tfms=[Resize(size=size)], #batch_tfms=[ToTensor(), IntToFloatTensor()],
                                  valid_pct=0.0,num_workers=12,device=device,seed=seed)


test_eq(len(dls.train_ds),50000)
test_eq(len(tune_dict[0].train_ds),512)

set(labels) #Check that the labels make sense
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='168173568' class='' max='168168549' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [168173568/168168549 00:02&lt;00:00]
#     </div>
# {'airplane',
#  'automobile',
#  'bird',
#  'cat',
#  'deer',
#  'dog',
#  'frog',
#  'horse',
#  'ship',
#  'truck'}

# %% [markdown]
# Test the random seed:

# %%
test_eq(fnames_train[0].name,'942_automobile.png')
test_eq(_val_dict[4][22].name,'26337_ship.png') #assumes dls_val corresponds to the 5th guy in tune_dict
test_eq(_val_dict[2][49].name,'33516_airplane.png')

# %% [markdown]
# Patch in definition of loss function (BT for now):

# %%
#Using BT
@patch
def lf(self:BarlowTwins, pred,*yb): return lf_bt(pred, self.I,self.lmb)

# %% [markdown]
# We also patch `before_epoch` so that we are training linear classifier:

# %% [markdown]
# Setup for linear evaluation:

# %%
aug_pipelines_val=[get_linear_batch_augs(size=size,stats=cifar_stats,resize_scale=(0.3, 1.0))]
main_linear_eval = Main_Linear_Eval(size=size,n_in=n_in,numfit=numfit,indim=1024, #size,n_in=3 (color channels),number of epochs to fit linear, and output dimension of encoder
                    dls_val=dls_val,dls_test=dls_test, #dls for training linear and evaluating linear
                    stats=cifar_stats,
                    aug_pipelines_val=aug_pipelines_val, #aug_pipeline for training 
                    encoder=None#encoder
                                )

# %% [markdown]
# Optional: Show linear augmentations:

# %%
show_linear_batch(dls=dls_val,n_in=n_in,n=2,aug=aug_pipelines_val,print_augs=True)
# Out:
# Pipeline: RandomResizedCrop -> Normalize -- {'mean': tensor([[[[0.4910]],
#
#          [[0.4820]],
#
#          [[0.4470]]]], device='cuda:0'), 'std': tensor([[[[0.2470]],
#
#          [[0.2430]],
#
#          [[0.2610]]]], device='cuda:0'), 'axes': (0, 2, 3)}
# Pipeline:

# %% [markdown]
# Patch linear evaluation into `after_epoch:`

# %%
@patch
def after_epoch(self:BarlowTwins):

    if (self.epoch+1)%150 !=0: #Every 250th epoch train linear evaluation
        return 

    #Put in eval mode and turn gradients off
    self.learn.eval()
    grad_on(self.learn.model,on=False)
    
    #Test in eval mode
    test_eq(self.learn.model.training,False)
    #Test gradients off
    test_grad_off(self.learn.model)

    ##########
    main_linear_eval.encoder = self.learn.model.encoder #Update the encoder
    self.acc_dict[self.epoch] = {}
    for i in range(num_val):
        dls_val = tune_dict[i]
        
        #Update tune set and model
        main_linear_eval.dls_val = dls_val
        main_linear_eval.model = LinearModel(encoder=main_linear_eval.encoder,indim=indim) #update the model (frozen encoder + head)


        acc = main_linear_eval() #train linear head on frozen encoder and get accuracy on test set
        self.acc_dict[self.epoch][i]=acc #update the acc_dict
    
    self.acc_dict[self.epoch]['mean'] = mean(list(self.acc_dict[self.epoch].values()))
    print(f"After epoch {self.epoch} mean acc of linear eval is {self.acc_dict[self.epoch]['mean']}")
    print(self.acc_dict)
    ##########
    
    #Put in train mode and turn gradients back on
    self.learn.train()
    grad_on(self.learn.model,on=True)

    #Test training mode on
    test_eq(self.learn.model.training,True)
    #Test gradients on
    test_grad_on(self.learn.model)

    if self.epoch+1 == self.learn.n_epoch:
        self.learn.save ('delthis', with_opt=True, pickle_protocol=2)

# %% [markdown]
# Define encoder and model; Define augmentation pipelines; Define learner.

# %%
fastai_encoder = create_fastai_encoder(xresnet34(),pretrained=False,n_in=n_in)

#If we are using a different model, this call will just look like `create_rat_model(...)`
model = create_barlow_twins_model(fastai_encoder, hidden_size=ps,projection_size=ps,nlayers=3)

aug_pipelines_1 = get_barlow_twins_aug_pipelines(size=size,
                                                 bw=True, rotate=True,noise=True, jitter=True, blur=True,solar=True,
                                                 resize_scale=(0.4, 1.0),rotate_deg=45,noise_std=0.0125, jitter_s=1.0, blur_s=math.ceil(size/10)+1,
                                                 bw_p=0.2, flip_p=0.5,rotate_p=0.25,noise_p=0.5, jitter_p=0.5, blur_p=0.5,sol_p=0.0,
                                                 stats=cifar_stats,same_on_batch=False, xtra_tfms=[]
                                                 )

aug_pipelines_2 = get_barlow_twins_aug_pipelines(size=size,
                                                 bw=True, rotate=True,noise=True, jitter=True, blur=True,solar=True,
                                                 resize_scale=(0.4, 1.0),rotate_deg=45,noise_std=0.0125, jitter_s=1.0, blur_s=math.ceil(size/10)+1,sol_t=0.01,sol_a=0.01,
                                                 bw_p=0.2, flip_p=0.5,rotate_p=0.25,noise_p=0.5, jitter_p=0.5, blur_p=0.1,sol_p=0.2,
                                                 stats=cifar_stats,same_on_batch=False, xtra_tfms=[]
                                                 )

aug_pipelines = [aug_pipelines_1,aug_pipelines_2]
aug_pipelines = [aug_pipelines_1,aug_pipelines_2]

#If we are using a different `callback` to `BarlowTwins` then we can simply replace `BarlowTwins` with 
#e.g. `BarlowTriplets`. We can define in base_model and just import with no issues. 
learn = Learner(dls,model, cbs=[BarlowTwins(aug_pipelines,n_in=n_in,lmb=1/ps,print_augs=False)])
#Set path of learn correctly
learn.path = Path('/content/drive/MyDrive/')

# %%
learn.fit(n_epoch)
learn.barlow_twins.acc_dict
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='149' class='' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       24.83% [149/600 2:24:54&lt;7:18:37]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>90.980057</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>78.163078</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>70.578400</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>66.475655</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>61.993599</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>61.174114</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>57.294300</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>52.899639</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>51.378742</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>50.252209</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>47.970123</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>50.759022</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>47.339943</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>45.521503</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>45.563675</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>48.334648</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>46.051994</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>44.151398</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>41.907604</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>42.429413</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>42.326412</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>39.997845</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>40.248348</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>40.345203</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>39.149414</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>37.304222</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>38.392170</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>36.649300</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>36.914780</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>35.322521</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>36.578194</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>33.767117</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>34.451965</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>33.007011</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>36.988857</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>34.536144</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>34.444416</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>35.230385</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>31.915047</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>31.460318</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>33.890587</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>32.773190</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>31.429216</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>32.534744</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>31.826330</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>31.974997</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>33.148361</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>33.667809</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>30.721180</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>30.307783</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>30.049076</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>32.291584</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>30.308508</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>30.119061</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>31.451910</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>30.177433</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>28.588850</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>28.913389</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>28.393232</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>28.431589</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>29.644890</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>28.559420</td>
#       <td>None</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>31.195284</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>28.314964</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>27.911295</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>27.500343</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>28.696909</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>29.277718</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>27.731035</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>27.332602</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>26.623581</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>26.692701</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>27.129705</td>
#       <td>None</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>25.866755</td>
#       <td>None</td>
#       <td>00:58</td>
#     </
# /usr/local/lib/python3.7/dist-packages/fastprogress/fastprogress.py:73: UserWarning: Your generator is empty.
#   warn("Your generator is empty.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.162334</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.909480</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.730100</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.571759</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.444724</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.340166</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.267229</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.193882</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.144593</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.089496</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.049372</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.021473</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.982610</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.960050</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.943956</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.916990</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.906905</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.890992</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.865334</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.850773</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.829475</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.806946</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.793094</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.775444</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.765659</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.754856</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.751105</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.734251</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.731716</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.739785</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.725676</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.708096</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.697342</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.684523</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.682156</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.669793</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.666308</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.660592</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.647672</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.637895</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.627976</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.619794</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.612121</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.612632</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.602008</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.596398</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.586803</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.592874</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.583236</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.579336</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.570241</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.561670</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.555871</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.547443</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.540202</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.536465</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.540306</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.538632</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.538630</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.527296</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.536819</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.536118</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.526211</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.518942</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.519749</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.514497</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.509279</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.504451</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.501600</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.494769</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.490772</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.481743</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.472649</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.469399</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.477732</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.468418</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.468034</td>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='23' class='' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       11.50% [23/200 00:44&lt;05:43]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.216470</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.955280</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.768572</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.603712</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.472639</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.367321</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.277125</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.217123</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.159274</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.121572</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.087102</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.044536</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.004779</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.968304</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.943025</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.928739</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.912449</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.895515</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.886346</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.880399</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.875810</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.854105</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.839191</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='0' class='' max='0' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100% [0/0]
#     </div>

# %% [markdown]
# Step 3): (Optional): View the augmentations:

# %%
#show_bt_batch(dls=dls,n_in=n_in,aug=aug_pipelines,n=30,print_augs=True)

# %% [markdown]
# Step 4): Fit the learner:

# %%
#learn = learn.load (file=Path('/content/drive/MyDrive/models/delthis'), device=device, with_opt=True, strict=True)

# %%
#This will also perform linear evaluation every x epochs (see `before_batch`) above 
learn.fit(n_epoch)
learn.barlow_twins.acc_dict
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='237' class='' max='600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       39.50% [237/600 3:34:46&lt;5:28:57]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>90.725105</td>
#       <td>None</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>78.087509</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>70.513573</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>66.641785</td>
#       <td>None</td>
#       <td>00:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>62.079796</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>61.311615</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>57.358116</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>53.039448</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>51.828415</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>50.150105</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>48.220745</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>50.722511</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>47.666222</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>45.475948</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>45.518669</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>48.521397</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>46.078106</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>44.435551</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>42.051773</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>42.614338</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>42.665550</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>40.200623</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>40.329239</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>40.333206</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>39.153656</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>37.330967</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>38.819244</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>36.832512</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>37.095379</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>35.319256</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>36.990303</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>33.978302</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>34.569290</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>33.223385</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>37.485939</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>34.501232</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>34.595337</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>35.519947</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>31.753841</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>31.666981</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>34.082268</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>32.727993</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>31.751148</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>32.393711</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>31.912109</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>31.921602</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>33.130608</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>33.930962</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>30.785191</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>30.559156</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>30.009941</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>32.400097</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>30.468807</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>30.152967</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>31.342173</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>29.972469</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>28.452791</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>28.759520</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>28.203510</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>28.562399</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>29.307547</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>28.491978</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>31.138243</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>27.986675</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>27.998951</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>27.581097</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>28.412653</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>29.249239</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>27.539747</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>27.183399</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>26.573851</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>26.377665</td>
#       <td>None</td>
#       <td>00:46</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>26.886253</td>
#       <td>None</td>
#       <td>00:47</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>25.726685</td>
#       <td>None</td>
#       <td>00:46</td>
#     </
# /usr/local/lib/python3.7/dist-packages/fastprogress/fastprogress.py:73: UserWarning: Your generator is empty.
#   warn("Your generator is empty.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.109115</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.854825</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.680660</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.520980</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.394694</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.293293</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.218673</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.148336</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.103617</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.052595</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.014716</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.989254</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.950180</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.926355</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.911750</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.887102</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.881669</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.867633</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.843616</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.827754</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.805416</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.782403</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.769557</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.750317</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.741269</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.729239</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.725845</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.708509</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.705102</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.714620</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.699936</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.683372</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.673277</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.661945</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.660921</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.648210</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.644310</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.640173</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.627972</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.617278</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.607569</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.600326</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.592841</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.594392</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.584681</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.578321</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.569446</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.574841</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.565598</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.563266</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.553820</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.545374</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.540867</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.531253</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.522638</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.518498</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.522545</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.522971</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.528808</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.517718</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.529103</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.528443</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.518520</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.511297</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.511165</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.506718</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.501569</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.494019</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.494653</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.488312</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.482641</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.471556</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.461454</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.458607</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.466142</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.455653</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.458112</td>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.177408</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.923183</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.738798</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.578611</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.452307</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.348919</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.257287</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.200268</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.139169</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.101391</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.068535</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.025049</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.984634</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.949795</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.924161</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.907717</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.891303</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.874307</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.865105</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.858102</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.850753</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.830968</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.816873</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.797696</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.780804</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.760652</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.742282</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.731823</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.715554</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.705015</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.690743</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.678339</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.682018</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.680993</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.671691</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.666509</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.656038</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.651280</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.650022</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.650889</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.644804</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.628964</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.621753</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.617667</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.608953</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.602771</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.588697</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.585080</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.574559</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.571702</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.567086</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.559254</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.565276</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.553081</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.548278</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.546893</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.536326</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.529504</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.523329</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.517159</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.515101</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.506174</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.524693</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.524119</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.512008</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.518406</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.505177</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.497037</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.489364</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.479238</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.483406</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.474552</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.466462</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.455714</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.452669</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.446201</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.439135</td>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.184180</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.932071</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.753064</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.600084</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.463624</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.355788</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.269140</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.197458</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.142778</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.101094</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.054080</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.023244</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.999120</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.967276</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.942152</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.922233</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.912226</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.888355</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.864767</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.858225</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.838655</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.814699</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.803704</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.792783</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.780065</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.773444</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.761319</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.750117</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.740704</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.736890</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.729716</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.710536</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.705895</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.691234</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.675154</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.662245</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.660028</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.653253</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.647306</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.637548</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.636329</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.620447</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.619261</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.611196</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.605180</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.596189</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.586124</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.578506</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.575482</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.575038</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.564954</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.557773</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.549826</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.541195</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.538823</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.538766</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.524784</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.515912</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.517920</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.516950</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.510063</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.503953</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.498252</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.493240</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.491754</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.490980</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.496827</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.496321</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.489756</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.485220</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.501751</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.503742</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.523979</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.516017</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.508849</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.510713</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.519223</td>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.124274</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.865446</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.660371</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.493956</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.360960</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.254698</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.186022</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.114431</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.065442</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.010861</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.968682</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.934713</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.906813</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.885188</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.861611</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.832100</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.807613</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.788680</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.776690</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.763226</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.747774</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.734537</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.720254</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.702886</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.685064</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.671887</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.664666</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.652308</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.643682</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.631544</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.621274</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.613763</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.614316</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.619528</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.623847</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.614201</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.602553</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.592760</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.581009</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.577789</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.571375</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.566531</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.561724</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.555736</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.559099</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.558534</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.548238</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.536781</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.534471</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.529804</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.523983</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.520679</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.508089</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.515377</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.507254</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.504329</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.501797</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.511769</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.507891</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.504926</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.506559</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.498862</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.493526</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.483068</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.484595</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.482971</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.473716</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.468550</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.460686</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.463641</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.453403</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.452626</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.443360</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.447526</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.448615</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.444499</td>
#       <td>None</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.436696</td>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.161973</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.916275</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.730538</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.567140</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.441364</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.336832</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.247072</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.183424</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.122675</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.072676</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.038184</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.005378</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.973369</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.941229</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.921273</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.900442</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.876697</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.858045</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.848113</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.836382</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.821023</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.798764</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.785553</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.767029</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.764102</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.758145</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.740320</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.729109</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.713161</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.704227</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.691817</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.680184</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.673554</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.673621</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.666051</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.655208</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.655930</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.646780</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.641051</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.633938</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.622950</td>
#       <td>None</td>
#       <td>00:01</td>
#     </tr>
# ...
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.907940</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.890508</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.867290</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.853461</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.826852</td>
#       <td>None</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.809597</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.788381</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.765396</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.746278</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.728776</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.712962</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.693515</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.684746</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.688804</td>
#       <td>None</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.690613</td>
#       <td>None</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.676526</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.657339</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.652260</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.642137</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.630403</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.619244</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.601632</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.593130</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.586432</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.579396</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.575989</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.575113</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.564310</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.554114</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.547838</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.543309</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.533447</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.524167</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.522804</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.509368</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.498729</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.491145</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.485717</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.476948</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.475364</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.481126</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.478830</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.475490</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.467630</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.465832</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.466173</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.463742</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.454767</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.457661</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.463337</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.457025</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.451919</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.448958</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.448182</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.441050</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.438639</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.436997</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.432968</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.429156</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.443332</td>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.259155</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.099025</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.936477</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.809279</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.690388</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.593151</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.503038</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.416505</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.347712</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.291326</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.235652</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.192199</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.152621</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.114036</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.080445</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.045180</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.014386</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.991206</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.971045</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.949000</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.924857</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.903633</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.879471</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.855228</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.843326</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.834055</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.813926</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.810686</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.798730</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.783672</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.775626</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.762358</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.749616</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.740377</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.733314</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.721704</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.708965</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.693498</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.687653</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.678407</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.679551</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.674909</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.672903</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.663083</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.654412</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.641568</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.634337</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.631679</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.619580</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.612545</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.604452</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.591263</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.597145</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.598299</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.594557</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.582492</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.572578</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.574569</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.570885</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.562541</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.556502</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.560855</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.562376</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.556379</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.549987</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.546065</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>0.537704</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>0.531869</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>0.525141</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.515648</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.512616</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>0.503684</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.505160</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>0.519031</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.518732</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.511753</td>
#       <td>None</td>
#       <td>00:04</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.511682</td>
# After epoch 599 mean acc of linear eval is 0.7017400026321411
# {149: {0: 0.6854000091552734, 1: 0.6721000075340271, 2: 0.6751999855041504, 3: 0.6729999780654907, 4: 0.6660000085830688, 'mean': 0.6743399977684021}, 299: {0: 0.6995999813079834, 1: 0.7009999752044678, 2: 0.7056999802589417, 3: 0.7006000280380249, 4: 0.6771000027656555, 'mean': 0.6967999935150146}, 449: {0: 0.7020000219345093, 1: 0.7031000256538391, 2: 0.7042999863624573, 3: 0.6962000131607056, 4: 0.6825000047683716, 'mean': 0.6976200103759765}, 599: {0: 0.7053999900817871, 1: 0.695900022983551, 2: 0.7116000056266785, 3: 0.7073000073432922, 4: 0.6884999871253967, 'mean': 0.7017400026321411}}
# {149: {0: 0.6854000091552734,
#   1: 0.6721000075340271,
#   2: 0.6751999855041504,
#   3: 0.6729999780654907,
#   4: 0.6660000085830688,
#   'mean': 0.6743399977684021},
#  299: {0: 0.6995999813079834,
#   1: 0.7009999752044678,
#   2: 0.7056999802589417,
#   3: 0.7006000280380249,
#   4: 0.6771000027656555,
#   'mean': 0.6967999935150146},
#  449: {0: 0.7020000219345093,
#   1: 0.7031000256538391,
#   2: 0.7042999863624573,
#   3: 0.6962000131607056,
#   4: 0.6825000047683716,
#   'mean': 0.6976200103759765},
#  599: {0: 0.7053999900817871,
#   1: 0.695900022983551,
#   2: 0.7116000056266785,
#   3: 0.7073000073432922,
#   4: 0.6884999871253967,
#   'mean': 0.7017400026321411}}

# %%
#learn = learn.load (file=Path('/content/drive/MyDrive/models/delthis'), device=device, with_opt=True, strict=True)
#learn.fit(200)

# %%
 #load learner, at least within session... `(but you can view it in drive)
 #learn = learn.load (file=Path('/content/drive/MyDrive/models/delthis'), device=device, with_opt=True, strict=True)
